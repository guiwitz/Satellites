# %% [markdown]
# # Satellite elevation-azimuth diagrams and PDOP
# ### Guillaume Witz, Science IT Support, Bern University

# %% [markdown]
# ## Import packages

# %%
import os, re, glob
import numpy as np
import scipy.signal
import matplotlib.pyplot as plt
import pandas as pd
import urllib.request
from bz2 import BZ2File as bzopen

import ipywidgets as ipw
from ipywidgets import interact, interactive, fixed, interact_manual

import aiub

# %% [markdown]
# ## User parameters

# %%
#file location
address = 'http://ftp.aiub.unibe.ch/users/darnold/Python/'
#station coordinates file
coord_file = 'IGS14.CRD'
#station to observe
station_name = '14001M004'
#number of days to observe (starting from day == 0)
numdays = 3

# %% [markdown]
# ## Elevation-azimuth
# #### Data import and computation

# %%
#import station data
stations = aiub.import_stations(address,coord_file)

# %%
#select station and calculate ellipsoidal coordinates
curr_stat = stations[stations.statname == station_name].iloc[0]
rad_stat_coord = aiub.cartesian_to_ellipsoidal(curr_stat.x_pos, curr_stat.y_pos,curr_stat.z_pos)
curr_stat['rad_stat_coord'] = rad_stat_coord

# %%
temp_pd
# Out:
#        index  year  month  day  hour  minute satellite  name            c1  \
# 0          0  2019      1    1     0       0       GPS  PG01  1.514994e+06
# 1          1  2019      1    1     0       0       GPS  PG02 -2.055908e+07
# 2          2  2019      1    1     0       0       GPS  PG03 -8.396509e+06
# 3          3  2019      1    1     0       0       GPS  PG04  1.307618e+07
# 4          4  2019      1    1     0       0       GPS  PG05 -1.152675e+07
# 5          5  2019      1    1     0       0       GPS  PG06 -2.519528e+07
# 6          6  2019      1    1     0       0       GPS  PG07 -1.437622e+07
# 7          7  2019      1    1     0       0       GPS  PG08  6.182801e+06
# 8          8  2019      1    1     0       0       GPS  PG09 -8.966383e+06
# 9          9  2019      1    1     0       0       GPS  PG10  2.303614e+07
# 10        10  2019      1    1     0       0       GPS  PG11  3.942280e+06
# 11        11  2019      1    1     0       0       GPS  PG12  4.608277e+06
# 12        12  2019      1    1     0       0       GPS  PG13 -1.264835e+07
# 13        13  2019      1    1     0       0       GPS  PG14  1.573856e+07
# 14        14  2019      1    1     0       0       GPS  PG15 -2.162266e+06
# 15        15  2019      1    1     0       0       GPS  PG16  1.209489e+07
# 16        16  2019      1    1     0       0       GPS  PG17 -1.409629e+07
# 17        17  2019      1    1     0       0       GPS  PG18  1.157153e+07
# 18        18  2019      1    1     0       0       GPS  PG19 -1.577710e+07
# 19        19  2019      1    1     0       0       GPS  PG20  2.270961e+07
# 20        20  2019      1    1     0       0       GPS  PG21  1.693182e+07
# 21        21  2019      1    1     0       0       GPS  PG22 -1.133720e+06
# 22        22  2019      1    1     0       0       GPS  PG23 -2.862549e+06
# 23        23  2019      1    1     0       0       GPS  PG24 -5.990328e+06
# 24        24  2019      1    1     0       0       GPS  PG25  1.512843e+07
# 25        25  2019      1    1     0       0       GPS  PG26  1.934431e+07
# 26103 2019-01-03 23:45:00  5.710387e+06  2.853948e+07 -3.700653e+07 -1.737212
# 26104 2019-01-03 23:45:00  2.110398e+07 -1.175017e+07  1.120696e+07  0.681780
# 26105 2019-01-03 23:45:00  1.063467e+07  1.690144e+07  1.557595e+07 -0.603334
# 26106 2019-01-03 23:45:00 -9.702769e+06  3.040467e+07  2.141440e+07 -1.335135
# 26107 2019-01-03 23:45:00  2.317186e+07  9.049015e+06 -2.268997e+07 -0.227148
# 26108 2019-01-03 23:45:00 -6.141926e+06  3.926909e+07  9.051317e+06 -1.383971
# 26109 2019-01-03 23:45:00 -2.165213e+07  2.474183e+07  2.400204e+07 -1.671409
# 26110 2019-01-03 23:45:00 -3.065483e+07  1.621329e+07 -2.196133e+07 -2.517298
# 26111 2019-01-03 23:45:00 -1.684794e+07  3.435374e+07 -1.766850e+07 -1.939251
#
#               e  curr_stat
# 0     -0.892468  40421M002
# 1      0.286726  40421M002
# 2     -0.521933  40421M002
# 3      0.249907  40421M002
# 4      0.898937  40421M002
# 5     -0.066881  40421M002
# 6      1.155945  40421M002
# 7     -0.083076  40421M002
# 8      0.670789  40421M002
# 9     -0.948665  40421M002
# 10    -0.690378  40421M002
# 11    -0.972959  40421M002
# 12     0.234317  40421M002
# 13    -1.205691  40421M002
# 14    -0.265245  40421M002
# 15     0.411896  40421M002
# 16    -0.722199  40421M002
# 17    -0.862618  40421M002
# 18    -0.679800  40421M002
# 19    -0.611531  40421M002
# 20     0.141337  40421M002
# 21    -0.772180  40421M002
# 22     0.196013  40421M002
# 23    -0.826482  40421M002
# 24    -0.844875  40421M002
# 25     0.087429  40421M002
# 26     0.118674  40421M002
# 27    -0.119798  40421M002
# 28     0.071966  40421M002
# 29     0.802338  40421M002
# ...         ...        ...
# 26082  0.818677  40421M002
# 26083 -0.079529  40421M002
# 26084 -0.515469  40421M002
# 26085 -0.334189  40421M002
# 26086 -0.364259  40421M002
# 26087  0.107138  40421M002
# 26088 -0.349309  40421M002
# 26089  0.269692  40421M002
# 26090  0.729769  40421M002
# 26091 -0.500167  40421M002
# 26092 -1.005645  40421M002
# 26093 -0.690899  40421M002
# 26094  0.076275  40421M002
# 26095 -0.546532  40421M002
# 26096  0.165670  40421M002
# 26097 -0.773207  40421M002
# 26098  0.321243  40421M002
# 26099  0.253526  40421M002
# 26100 -0.786450  40421M002
# 26101  0.476312  40421M002
# 26102 -0.164831  40421M002
# 26103 -0.971942  40421M002
# 26104  0.098731  40421M002
# 26105  0.313648  40421M002
# 26106  0.549526  40421M002
# 26107 -1.177699  40421M002
# 26108  0.159329  40421M002
# 26109  0.758179  40421M002
# 26110 -0.217351  40421M002
# 26111 -0.305603  40421M002
#
# [26112 rows x 21 columns]

# %%
#import satellite data
temp_pd = pd.concat([aiub.import_RM_file(address = address, day = i) for i in range(numdays)]).reset_index()
#reanme satellite types
sat_dict = {'G':'GPS','R':'GLONASS','E':'Galileo','C':'BeiDou','J':'QZSS'}
temp_pd['satellite'] = temp_pd.satellite.apply(lambda x : sat_dict[x])

# %%
#caluclate elevation and azimuth for all satellites for given station
temp_pd = aiub.el_al_single_station_fast(temp_pd, curr_stat)
temp_pd['curr_stat'] = curr_stat.statname

# %% [markdown]
# ### Plotting

# %%
aiub.interactive_rad(temp_pd, stations)
# Out:
# VBox(children=(HBox(children=(SelectMultiple(index=(0,), options=('GPS', 'GLONASS', 'Galileo', 'BeiDou', 'QZSS…
# Output()

# %% [markdown]
# ## PDOP

# %% [markdown]
# ### User input

# %%
#how many days to include for calculation
numdays = 10

# %% [markdown]
# ### Data import and calculation

# %%
#import data and compute elevation-azimuth
temp_pd = pd.concat([aiub.import_RM_file(address = address, day = i) for i in range(numdays)]).reset_index()
temp_pd = aiub.el_al_single_station_fast(temp_pd, curr_stat)

# %%
#remove elevation < 5°
temp_pd = temp_pd[temp_pd.e >2*np.pi*5/360]

# %%
#calculate norm of satellite-station vector Xgeo
temp_pd['Xgeo_norm'] = temp_pd.apply(lambda row: np.linalg.norm([row['Xgeo'],row['Ygeo'],row['Zgeo']]),axis = 1)

# %%
#group data by chuncks of 30min
time_grouped = temp_pd.groupby(pd.Grouper(key='datetime', freq='30min', axis=1))

# %%
#calculate pdop for each group
pdop = dict((key, []) for key in temp_pd.satellite.unique())

for name, df0 in time_grouped:
    sat_grouped = df0.groupby('satellite')
    for name2, df in sat_grouped:
        A_mat = np.stack([-df['Xgeo']/df['Xgeo_norm'],-df['Ygeo']/df['Xgeo_norm'],
              -df['Zgeo']/df['Xgeo_norm'],np.ones(len(df))],axis = 1)

        try:
            inv_mat = np.linalg.inv(np.matmul(A_mat.T,A_mat))
        except:
            False

        pdop[name2].append(np.sqrt(inv_mat[0,0]+inv_mat[1,1]+inv_mat[2,2]))
# Out:
# /Users/gw18g940/miniconda3/envs/astronomy/lib/python3.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in sqrt
#   from ipykernel import kernelapp as app

# %%
#calculate power spectrum and set the right (?) scale 
powerspec = {}
for x in pdop.keys():
    powerspec[x] = scipy.signal.periodogram(pdop[x],fs = 2/3600)#, scaling='spectrum')

# %% [markdown]
# ### Plotting

# %%
#define interactive plotting function 
def plot_pdop(sat_type, pdop):
    fig, ax = plt.subplots(2,1)
    for s in sat_type:
        ax[0].plot(np.arange(len(pdop[s]))/(24*2),pdop[s], label = s)
        
        ax[1].plot(powerspec[s][0]*3600*24,powerspec[s][1], label = s)
    ax[0].legend()
    ax[1].set_xlim((0,5))
    plt.show()

# %%
ipw.interactive(plot_pdop, sat_type = ipw.SelectMultiple(options =temp_pd.satellite.unique()),
                pdop = ipw.fixed(pdop))
# Out:
# interactive(children=(SelectMultiple(description='sat_type', options=('G', 'R', 'E', 'C'), value=()), Output()…
